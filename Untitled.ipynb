# %%
import pandas as pd

# %%
data = pd.read_csv('Climat-2021-2051-8.5-ete-hiver-raw.csv');

# %%
print(data.tail())
# Out:
#        # Point  Latitude  Longitude Contexte Période  Saison  NORTAV  NORTNAV  \
# 17199    18802   50.9779     2.5069   RCP8.5      H1       3   17.20    14.85
# 17200    18944   51.0497     2.3934   RCP8.5      H1       1    5.93     4.23
# 17201    18944   51.0497     2.3934   RCP8.5      H1       3   17.23    14.88
# 17202    18945   51.0496     2.5071   RCP8.5      H1       1    5.92     4.22
# 17203    18945   51.0496     2.5071   RCP8.5      H1       3   17.21    14.85
#
#        NORTXAV  NORTRAV   ...     AHDD   ACDD  APAV  APINT    ARR  APFL90  \
# 17199    19.56     4.71   ...   -41.35  21.73  0.28   1.04  25.75    0.77
# 17200     7.62     3.38   ...   -99.64   0.00  0.19  -0.05  17.23   -6.06
# 17201    19.58     4.69   ...   -42.50  22.31  0.20   0.70  17.91    0.53
# 17202     7.63     3.41   ...   -99.66   0.00  0.20  -0.01  17.79   -6.53
# 17203    19.57     4.71   ...   -41.30  21.78  0.28   1.05  25.73    0.77
#
#        ARR1MM  APXCWD  APN20MM  APXCDD
# ...

# %%
data['# Point'].unique()
# Out:
# array([  282,   423,   424, ..., 18802, 18944, 18945])

# %%
data = data.drop_duplicates(subset='# Point')

# %%
data
# Out:
#        # Point            Latitude           Longitude Contexte Période  \
# 0          282             41.4087              9.1577   RCP8.5      H1
# 2          423             41.4925              8.9759   RCP8.5      H1
# 4          424             41.4864               9.071   RCP8.5      H1
# 6          425             41.4802               9.166   RCP8.5      H1
# 8          426             41.4739   9.261000000000001   RCP8.5      H1
# 10         564             41.5759              8.7935   RCP8.5      H1
# 12         565               41.57              8.8888   RCP8.5      H1
# 14         566   41.56399999999999               8.984   RCP8.5      H1
# 16         567             41.5579              9.0791   RCP8.5      H1
# 18         568             41.5517              9.1743   RCP8.5      H1
# 20         569             41.5454              9.2694   RCP8.5      H1
# 22         707             41.6474              8.8014   RCP8.5      H1
# ...

# %%
data.to_csv("lol.csv", encoding='utf-8', index=False)
